# %% [markdown]
# # [주제명]
#
# **학습 날짜**: YYYY-MM-DD
# **참고 자료**: [W3Schools 링크]

# %% [markdown]
# ## 학습 내용
#
# ### 주요 개념
#
# -
# -
# -

# %% [markdown]
# ## Python 코드 실습

# %%
# 코드 작성

# %%
# 추가 코드 (필요시)

# %% [markdown]
# ## Java와의 비교
#
# ### 문법 차이
#
# **Python:**
# ```python
# # Python 코드
# ```
#
# **Java:**
# ```java
# // Java 코드
# ```
#
# ### 개념적 차이
#
# - Python:
# - Java:

# %% [markdown]
# ## 정리
#
# ### 핵심 내용
#
# 1.
# 2.
# 3.
#
# ### 느낀 점
#
# -
# -
