# %% [markdown]
# # Python Tutorial

# %% [markdown]
# ## 🐍 Python vs ☕ Java 소개 정리
#
# 이 문서는 W3Schools의 Python 및 Java 소개 내용을 바탕으로 **비교 정리한 문서**입니다.
#   - reference
#     - https://www.w3schools.com/Python/Python_intro.asp
#     - https://www.w3schools.com/java/java_intro.asp
#
# ---
#
# ### 🐍 What is Python?
# Python은 매우 인기 있는 프로그래밍 언어입니다.
# Guido van Rossum이 만들었고, **1991년에 처음 출시**되었습니다.
#
# ### 🧾 Python의 활용 분야
# - 웹 개발 (서버 사이드)
# - 소프트웨어 개발
# - 수학/과학 계산
# - 시스템 스크립팅
#
# ---
#
# ### 🛠 What can Python do?
# - 서버에서 웹 애플리케이션을 만들 수 있음
# - 다양한 소프트웨어와 연동하여 워크플로우 자동화 가능
# - 데이터베이스 시스템 연결, 파일 읽기/쓰기 가능
# - 빅데이터 처리 및 복잡한 수학 계산 수행
# - 프로토타입(시제품) 개발부터 실제 서비스 개발까지 모두 가능
#
# ---
#
# ### ⭐ Why Python? (파이썬을 쓰는 이유)
# - Windows, Mac, Linux, Raspberry Pi 등 다양한 플랫폼에서 실행 가능
# - 영어에 가까운 단순하고 직관적인 문법
# - 다른 언어보다 **더 적은 코드 줄 수**로 동일한 기능 구현 가능
# - 인터프리터 방식 → 코드를 작성하자마자 즉시 실행 가능 → **빠른 개발 속도**
# - 절차적(Procedural), 객체지향(OOP), 함수형(Function) 방식 모두 지원
#
# ---
#
# ### 📌 Good to Know (알아두면 좋은 점)
# - 최신 주요 버전은 **Python 3**이며, 본 튜토리얼에서도 Python 3 기준
# - 텍스트 에디터에서 코드를 작성할 수 있음
# - Thonny, PyCharm, NetBeans, Eclipse 같은 IDE에서 개발할 수도 있으며
#   특히 많은 Python 파일을 관리할 때 유용함
#
# ---
#
# ### 🔤 Python Syntax vs 다른 언어
# - **읽기 쉬운 문법** (영어 + 수학 스타일 영향)
# - 대부분의 언어가 ;(세미콜론)으로 명령을 끝내는 것과 달리
#   → Python은 **줄바꿈(New line)** 으로 명령을 완료
# - 들여쓰기(Indentation)를 사용해 범위(Scope)를 정의
#   → 반복문, 함수, 클래스 등
# - 다른 언어(C, Java, C++, JS 등)는 `{}`(중괄호)를 범위 지정에 사용함
#
# ---
#
# ### ☕ What is Java?
# Java는 강력하고 인기 있는 프로그래밍 언어로, **1995년에 출시**되었습니다.
# 현재 Java는 Oracle이 관리하고 있으며, **30억 개 이상의 기기에서 Java가 실행**되고 있습니다.
#
# ### 🧾 Java의 활용 분야
# - 모바일 앱(특히 안드로이드)
# - 데스크톱 애플리케이션
# - 웹 애플리케이션
# - 웹 서버 / 애플리케이션 서버
# - 게임 개발
# - 데이터베이스 연동
# - 그 외 수많은 분야에서 사용
#
# ---
#
# ### ⭐ Why Use Java? (자바를 쓰는 이유)
# - 다양한 플랫폼(Windows, Mac, Linux, Raspberry Pi 등)에서 실행 가능
# - 세계에서 가장 인기 있는 프로그래밍 언어 중 하나
# - 현재 IT 취업 시장에서 지속적인 수요
# - 배우기 쉽고 사용하기 쉬움
# - 오픈소스이며 무료
# - 빠르고 안전하며 강력함
# - 수천만 명 규모의 대규모 커뮤니티
# - 명확한 구조를 제공하는 **객체지향 언어(OOP)**
#   → 코드 재사용성 증가 → 개발 비용 절감
# - C++ 또는 C#과 유사하여 다른 언어로의 전환이 용이
#
# ---
#
# ### 📘 Python vs Java 간단 비교
#
# | 항목 | Python | Java |
# |------|--------|-------|
# | 출시 | 1991 | 1995 |
# | 실행 방식 | 인터프리터 | 컴파일 + JVM |
# | 문법 | 간결, 영어 같음 | 엄격하고 구조적 |
# | 범위(Scope) | 들여쓰기 | 중괄호 `{ }` |
# | 속도 | 상대적으로 느림 | 상대적으로 빠름 |
# | 스타일 | 절차적 + OOP + 함수형 | OOP 중심 |
# | 사용 분야 | 데이터/AI/웹/자동화 | 대규모 서비스, 앱, 서버 |
# | 난이도 | 쉬움 | 조금 더 엄격함 |
#
# ---
#
# ### 🎯 요약
# - Python → **쉽고 빠르게 개발**, AI·데이터·웹·자동화에 강함
# - Java → **안정적이며 대규모 개발에 최적화**, 기업 서비스·안드로이드에 강함
#
# 둘 다 매우 강력한 언어이며, 서로 다른 장점이 있으므로 목적에 따라 선택하면 됩니다.

# %% [markdown]
# - Python

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# - Java
#     ```java
#     public class Main {
#         public static void main(String[] args) {
#             System.out.println("Hello World");
#         }
#     }
#     ```

# %% [markdown]
# - Python version check

# %%
import sys

print(sys.version)
# Out:
# 3.13.2 (tags/v3.13.2:4f8bb39, Feb  4 2025, 15:23:48) [MSC v.1942 64 bit (AMD64)]

# %% [markdown]
# - Java version check
#     ```bash
#     java -version
#     ```

# %% [markdown]
# - Python indentation (들여쓰기)
#   - 들여쓰기는 코드 줄의 시작 부분에 있는 공백을 말합니다.
#   - 다른 프로그래밍 언어에서는 코드의 들여쓰기가 가독성을 위한 것일 뿐이지만, Python에서는 들여쓰기가 매우 중요합니다.
#   - 파이썬은 들여쓰기를 사용하여 코드 블록을 나타냅니다.
#   - 공백의 개수는 프로그래머의 선택에 달려 있습니다. 가장 일반적인 사용은 4개이지만, 최소한 1개는 있어야 합니다.
#   - 동일한 코드 블록에서 동일한 수의 공백을 사용해야 합니다. 그렇지 않으면 Python에서 오류가 발생합니다.

# %%
if 5 > 2:
    print("Five is greater than two!")

if 5 > 2:
        print("Five is greater than two!")
# Out:
# Five is greater than two!
# Five is greater than two!

# %% [markdown]
# - Python variables (변수)
#   - Python에서는 변수에 값을 할당하면 변수가 생성됩니다.

# %%
x = 5
y = "Hello, World!"

print(x)
print(y)
# Out:
# 5
# Hello, World!

# %% [markdown]
# - Python comments (주석)
#   - 파이썬은 코드 내 문서화를 위해 주석 기능을 갖추고 있습니다.
#   - 주석은 #으로 시작하고, Python은 해당 줄의 나머지 부분을 주석으로 처리합니다.

# %%
# This is comment.
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# - Java main method
#   - 이 main()메서드는 모든 Java 프로그램에 필수입니다. 프로그램이 시작되는 지점은 다음과 같습니다.
#       ```java
#       public static void main(String[] args)
#       ```
#   - 메서드 내부에 배치된 모든 코드는 main()실행됩니다.
#   - public지금은 키워드 , static, 를 이해할 필요가 없습니다 void. 이 튜토리얼의 뒷부분에서 이에 대해 알아보겠습니다. main()모든 Java 프로그램의 시작점은 이라는 점만 기억하세요.
#   - 각 Java 명령문은 세미콜론( ;)으로 끝나야 합니다.

# %% [markdown]
# - Java system.out.println()
#     - 메서드 내부에서 메서드 main()를 사용하여 println() 화면에 텍스트 줄을 인쇄할 수 있습니다.
#     ```java
#     public static void main(String[] args) {
#         System.out.println("Hello, World!");
#     }
#     ```

# %% [markdown]
# - Python statements (명령문)
#   - 컴퓨터 프로그램은 컴퓨터가 "실행"해야 하는 "명령어"들의 목록입니다.
#   - 프로그래밍 언어에서는 이러한 프로그래밍 명령을 명령문이라고 합니다.
#   - Python에서는 일반적으로 줄이 끝나면 명령문도 끝납니다. 다른 프로그래밍 언어(예: Java 또는 C)처럼 세미콜론(;)을 사용할 필요가 없습니다.

# %%
print("Python is fun!")

# %% [markdown]
# - Python many statements
#   - 대부분의 파이썬 프로그램은 여러 문장으로 구성됩니다.
#   - 명령문은 작성된 순서대로 하나씩 실행됩니다.

# %%
print("Hello World!")
print("Have a good day.")
print("Learning Python is fun!")
# Out:
# Hello World!
# Have a good day.
# Learning Python is fun!

# %% [markdown]
# - Python semicolons (Optional, Rarely Used) (세미콜론, 선택 사항, 거의 사용되지 않음)
#   - 세미콜론은 파이썬에서 선택 사항입니다. ;로 구분하여 여러 문장을 한 줄에 작성할 수 있지만, 읽기 어려워서 거의 사용되지 않습니다.
#   - 구분 기호(줄 바꿈 또는 ;) 없이 두 개의 문장을 같은 줄에 입력하면 Python에서 오류가 발생합니다.

# %%
print("Hello"); print("How are you?"); print("Bye bye!")

# SyntaxError: invalid syntax
# print("Python is fun!") print("Really!")
# Out:
# Hello
# How are you?
# Bye bye!

# %% [markdown]
# - Java statements
#   - 컴퓨터 프로그램은 컴퓨터가 "실행"해야 하는 "명령어"들의 목록입니다.
#   - 프로그래밍 언어에서는 이러한 프로그래밍 명령어를 명령문이라고 합니다.
#   ```java
#   System.out.println("Java is fun!");
#   ```
#   - 명령문은 세미콜론(;)으로 끝내는 것이 중요합니다.
#   - 세미콜론(;)을 생략하면 오류가 발생하고 프로그램이 실행되지 않습니다.
#   ```java
#   // error: ';' expected
#   System.out.println("Java is fun!")
#   ```
#   - 명령문은 영어의 문장과 같다고 생각하면 됩니다. 문장이 마침표(.)로 끝나는 것처럼, 자바 명령문은 세미콜론(;)으로 끝납니다.

# %% [markdown]
# - Java many statements
#   - 대부분의 Java 프로그램은 여러 개의 명령문을 포함합니다.
#   - 명령문은 작성된 순서대로 하나씩 실행됩니다.
#   ```java
#   System.out.println("Hello World!");
#   System.out.println("Have a good day!");
#   System.out.println("Learning Java is fun!");
#   ```

# %% [markdown]
# - Python Output / Print
#   - print() 함수는 원하는 만큼 사용할 수 있습니다. 각 호출은 기본적으로 새 줄에 텍스트를 인쇄합니다.
#   - Python에서 텍스트는 따옴표 안에 있어야 합니다. " 큰따옴표 또는 ' 작은따옴표를 사용할 수 있습니다.
#   - 기본적으로 print() 함수는 줄바꿈으로 끝납니다.
#   - 한 줄에 여러 단어를 출력하려면 end 매개변수를 사용할 수 있습니다.

# %%
print("Hello World!")
print("I am learning Python.")
print("It is awesome!")

print("This will work!")
print('This will also work!')

print("Hello World!", end=" ")
print("I will print on the same line.")
# Out:
# Hello World!
# I am learning Python.
# It is awesome!
# This will work!
# This will also work!
# Hello World! I will print on the same line.

# %% [markdown]
# - Java output / input
#   ```java
#   System.out.println("Hello World!");
#   ```
#   - 원하는 만큼 println() 메서드를 추가할 수 있습니다. 각 메서드마다 새 줄이 추가됩니다.
#   ```java
#   System.out.println("Hello World!");
#   System.out.println("I am learning Java.");
#   System.out.println("It is awesome!");
#   ```
#   - 텍스트는 큰따옴표("")로 묶어야 합니다.
#   - 큰따옴표를 생략하면 오류가 발생합니다.
#   ```java
#   System.out.println("This sentence will work!");
#   ```
#   - println()과 유사한 print() 메서드도 있습니다.
#   - 유일한 차이점은 출력 끝에 줄 바꿈을 삽입하지 않는다는 것입니다.
#   ```java
#   System.out.print("Hello World! ");
#   System.out.print("I will print on the same line.");
#   ```

# %% [markdown]
# - Python output numbers
#   - print() 함수를 사용하여 숫자를 표시할 수도 있습니다.
#   - 하지만 텍스트와 달리 큰따옴표 안에 숫자를 넣지 않습니다.
#   - print() 함수 내부에서도 수학 연산을 할 수 있습니다.
#   - 텍스트와 숫자를 쉼표로 구분하여 하나의 출력으로 결합할 수 있습니다.

# %%
print(3)
print(358)
print(50000)

print(3 + 5)
print(2 * 5)

print("I am", 35, "years old.")
# Out:
# 3
# 358
# 50000
# 8
# 10
# I am 35 years old.

# %% [markdown]
# - Java output numbers
#   - println() 메서드를 사용하여 숫자를 출력할 수도 있습니다.
#   - 하지만 텍스트와 달리 큰따옴표 안에 숫자를 넣지 않습니다.
#   ```java
#   System.out.println(3);
#   System.out.println(358);
#   System.out.println(50000);
#   ```
#   - println() 메서드 내부에서 수학적 계산을 수행할 수도 있습니다.
#   ```java
#   System.out.println(3 + 3);
#   System.out.println(2 * 5);
#   ```

# %% [markdown]
# - Python comments
#   - 주석은 Python 코드를 설명하는 데 사용할 수 있습니다.
#   - 주석은 코드의 가독성을 높이는 데 사용할 수 있습니다.
#   - 주석은 코드 테스트 시 실행을 방지하는 데 사용할 수 있습니다.
#   - 주석은 #으로 시작하며 Python은 이를 무시합니다.
#   - 주석은 줄의 끝에 넣을 수 있으며, Python은 줄의 나머지 부분을 무시합니다.
#   - 주석은 코드를 설명하는 텍스트일 필요는 없으며, Python이 코드를 실행하지 못하도록 하는 데에도 사용할 수 있습니다.
#   - Python에는 여러 줄 주석을 위한 구문이 없습니다.
#   - 여러 줄 주석을 추가하려면 각 줄에 #을 삽입하면 됩니다.
#   - 여러 줄 문자열을 사용할 수도 있습니다.
#   - Python은 변수에 할당되지 않은 문자열 리터럴을 무시하므로, 코드에 여러 줄 문자열(세 따옴표)을 추가하고 그 안에 주석을 넣을 수 있습니다.

# %%
# This is a comment
print("Hello, World!")

print("Hello, World!") # This is a comment

# print("Hello, World!")
print("Cheers, Mate!")

# This is a comment
# written in
# more than just one line
print("Hello, World!")

"""
This is a comment
written in
more than just one line
"""
print("Hello, World!")
# Out:
# Hello, World!
# Hello, World!
# Cheers, Mate!
# Hello, World!
# Hello, World!

# %% [markdown]
# - Java comments
#   - 주석은 Java 코드를 설명하고 가독성을 높이는 데 사용할 수 있습니다. 또한 대체 코드를 테스트할 때 실행을 방지하는 데에도 사용할 수 있습니다.
#   - 단일 줄 주석은 두 개의 슬래시(//)로 시작합니다.
#   - //와 줄 끝 사이의 모든 텍스트는 Java에서 무시됩니다(실행되지 않음).
#   ```java
#   // This is a comment
#   System.out.println("Hello World");
#
#   System.out.println("Hello World"); // This is a comment
#   ```
#   - 여러 줄 주석은 /*로 시작하고 */로 끝납니다.
#   - /*와 */ 사이의 모든 텍스트는 Java에서 무시됩니다.
#   ```java
#   /* The code below will print the words Hello World
#   to the screen, and it is amazing */
#   System.out.println("Hello World");
#   ```

# %% [markdown]
# - Python variables
#   - 변수는 데이터 값을 저장하는 컨테이너입니다.
#   - 변수 생성
#     - 파이썬에는 변수를 선언하는 명령이 없습니다.
#     - 변수는 처음 값을 할당하는 순간 생성됩니다.
#   - 변수는 특정 유형으로 선언될 필요가 없으며, 설정된 후에도 유형을 변경할 수 있습니다.
#   - 형변환
#     - 변수의 데이터 유형을 지정하려면 형변환을 사용할 수 있습니다.
#   - 데이터 유형 가져오기
#     - type() 함수를 사용하여 변수의 데이터 유형을 가져올 수 있습니다.
#   - 문자열 변수는 작은따옴표 또는 큰따옴표를 사용하여 선언할 수 있습니다.
#   - 대소문자 구분
#     - 변수 이름은 대소문자를 구분합니다.

# %%
x = 5
y = "John"
print(x)
print(y)

x = 4       # x is of type int
x = "Sally" # x is now of type str
print(x)

x = str(3)    # x will be '3'
y = int(3)    # y will be 3
z = float(3)  # z will be 3.0

x = 5
y = "John"
print(type(x))
print(type(y))

x = "John"
print(x)
# is the same as
x = 'John'
print(x)

a = 4
A = "Sally"
#A will not overwrite a
print(a)
print(A)
# Out:
# 5
# John
# Sally
# <class 'int'>
# <class 'str'>
# John
# John
# 4
# Sally

# %% [markdown]
# - Java variables
#   - 변수는 데이터 값을 저장하는 컨테이너입니다.
#   - Java에는 다음과 같은 다양한 유형의 변수가 있습니다.
#     - String - "Hello"와 같은 텍스트를 저장합니다. 문자열 값은 큰따옴표로 묶습니다.
#     - int - 123 또는 -123과 같이 소수점이 없는 정수(정수)를 저장합니다.
#     - float - 19.99 또는 -19.99와 같이 소수점이 있는 부동 소수점 숫자를 저장합니다.
#     - char - 'a' 또는 'B'와 같은 단일 문자를 저장합니다. Char 값은 작은따옴표로 묶습니다.
#     - boolean - true 또는 false의 두 가지 상태를 가진 값을 저장합니다.
#   - 변수 선언(생성)
#     - Java에서 변수를 생성하려면 다음을 수행해야 합니다.
#       - 형식(예: int 또는 String)을 선택합니다.
#       - 변수에 이름(예: x, age 또는 name)을 지정합니다.
#       - 선택적으로 =를 사용하여 값을 할당합니다.
#       ```java
#       type variableName = value;
#       ```
#   - 텍스트를 저장하려면 문자열을 사용할 수 있습니다.
#     - 문자열 유형의 name이라는 변수를 만들고 값 "John"을 할당합니다.
#     - 그런 다음 println()을 사용하여 name 변수를 출력합니다.
#     ```java
#     String name = "John";
#     System.out.println(name);
#     ```
#   - 숫자를 저장해야 하는 변수를 만들려면 int를 사용하면 됩니다.
#     - int 유형의 myNum이라는 변수를 만들고 값 15를 할당합니다.
#     ```java
#     int myNum = 15;
#     System.out.println(myNum);
#     ```
#   - 값을 할당하지 않고 변수를 선언한 다음 나중에 값을 할당할 수도 있습니다.
#     ```java
#     int myNum;
#     myNum = 15;
#     System.out.println(myNum);
#     ```
#   - 기존 변수에 새 값을 할당하면 이전 값이 덮어쓰여집니다.
#     - myNum 값을 15에서 20으로 변경합니다.
#     ```java
#     int myNum = 15;
#     myNum = 20;  // myNum is now 20
#     System.out.println(myNum);
#     ```
#   - final 변수
#     - 다른 사람(또는 자신)이 기존 값을 덮어쓰는 것을 원하지 않으면 final 키워드를 사용하세요(이 키워드는 변수를 "final" 또는 "constant"로 선언하여 변경할 수 없고 읽기 전용으로 만듭니다).
#     ```java
#     final int myNum = 15;
#     myNum = 20;  // will generate an error: cannot assign a value to a final variable
#     ```
#   - 다른 유형
#     - 다른 유형의 변수를 선언하는 방법
#     ```java
#     int myNum = 5;
#     float myFloatNum = 5.99f;
#     char myLetter = 'D';
#     boolean myBool = true;
#     String myText = "Hello";
#     ```
#   - print
#     - println() 메서드는 변수를 표시하는 데 자주 사용됩니다.
#     - 텍스트와 변수를 모두 결합하려면 + 문자를 사용합니다.
#     ```java
#     String name = "John";
#     System.out.println("Hello " + name);
#     ```
#   - `+` 문자를 사용하여 다른 변수에 변수를 추가할 수도 있습니다.
#   ```java
#   String firstName = "John ";
#   String lastName = "Doe";
#   String fullName = firstName + lastName;
#   System.out.println(fullName);
#   ```
#   - 자바에서 + 기호는 두 가지 의미를 갖습니다.
#     - 텍스트(문자열)의 경우, 문자열을 연결(concatenation)합니다.
#     - 숫자의 경우, 값을 더합니다.
#   - 숫자 값의 경우, + 문자는 수학 연산자로 작동합니다(여기서는 int(정수) 변수를 사용했습니다).
#   ```java
#   /*
#     x는 값 5를 저장합니다.
#     y는 값 6을 저장합니다.
#     println()은 x + y의 결과인 11을 표시합니다.
#   */
#
#   int x = 5;
#   int y = 6;
#   System.out.println(x + y); // Print the value of x + y
#   ```
#   - 텍스트와 숫자 혼합
#     - 같은 코드 줄에서 텍스트와 숫자를 함께 사용할 때는 주의하세요. 괄호가 없으면 Java는 첫 번째 문자열 이후의 숫자를 텍스트로 처리합니다.
#     ```java
#     /*
#       첫 번째 줄에서 Java는 "The sum is "와 x를 결합하여 "The sum is 5"라는 문자열을 생성합니다. 그런 다음 y를 해당 문자열에 더하여 "The sum is 56"이 됩니다.
#       두 번째 줄에서 괄호는 x + y를 먼저 계산하여 11을 출력하도록 합니다. 따라서 "The sum is 11"이 출력됩니다.
#     */
#     int x = 5;
#     int y = 6;
#
#     System.out.println("The sum is " + x + y);   // Prints: The sum is 56
#     System.out.println("The sum is " + (x + y)); // Prints: The sum is 11
#     ```

# %% [markdown]
# - Python - variable names
#   - 변수는 짧은 이름(예: x, y)이나 더 설명적인 이름(예: age, carname, total_volume)을 가질 수 있습니다.
#   - Python 변수 규칙:
#     - 변수 이름은 문자 또는 밑줄로 시작해야 합니다.
#     - 변수 이름은 숫자로 시작할 수 없습니다.
#     - 변수 이름은 영숫자 문자와 밑줄(A-z, 0-9, _)만 사용할 수 있습니다.
#     - 변수 이름은 대소문자를 구분합니다(age, Age, AGE는 세 개의 다른 변수입니다).
#     - 변수 이름은 Python 키워드를 사용할 수 없습니다.
#   - 여러 단어로 구성된 변수 이름
#     - 변수 이름이 두 개 이상인 경우 읽기 어려울 수 있습니다.
#     - 변수 이름을 더 읽기 쉽게 만드는 몇 가지 방법이 있습니다.
#   - Camel Case
#     - 첫 번째 단어를 제외한 모든 단어는 대문자로 시작합니다.
#   - Pascal Case
#     - 각 단어는 대문자로 시작합니다.
#   - nake Case
#     - 각 단어는 밑줄 문자로 구분됩니다.

# %%
myvar = "John"
my_var = "John"
_my_var = "John"
myVar = "John"
MYVAR = "John"
myvar2 = "John"

# Camel Case
myVariableName = "John"

# Pascal Case
MyVariableName = "John"

# Snake Case
my_variable_name = "John"

# %% [markdown]
# - Python variables - assign multiple values
#   - 여러 변수에 여러 값 할당
#     - Python에서는 한 줄로 여러 변수에 값을 할당할 수 있습니다.
#     - 변수의 개수와 값의 개수가 일치하는지 확인하세요. 일치하지 않으면 오류가 발생합니다.
#   - 여러 변수에 하나의 값 할당
#     - 한 줄에서 여러 변수에 같은 값을 할당할 수 있습니다.
#   - 컬렉션 압축 해제
#     - 리스트, 튜플 등의 형태로 값 컬렉션이 있는 경우, Python에서는 해당 값을 변수로 추출할 수 있습니다. 이를 압축 해제라고 합니다.

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)

x = y = z = "Orange"
print(x)
print(y)
print(z)

fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry
# Orange
# Orange
# Orange
# apple
# banana
# cherry

# %% [markdown]
# - Java declare multiple variables
#   - 여러 변수 선언
#     - 같은 유형의 변수를 여러 개 선언하려면 쉼표로 구분된 목록을 사용할 수 있습니다.
#     - 한 줄에 여러 변수를 선언하면 코드가 짧아지지만, 한 줄에 변수 하나씩 작성하면 코드를 읽기가 더 쉬워질 수 있습니다.
#     ```java
#     int x = 5;
#     int y = 6;
#     int z = 50;
#     System.out.println(x + y + z); // 61
#
#     int x = 5, y = 6, z = 50;
#     System.out.println(x + y + z); // 61
#     ```
#   - 여러 변수에 하나의 값 할당
#     - 한 줄에 여러 변수에 같은 값을 할당할 수도 있습니다.
#     ```java
#     int x, y, z;
#     x = y = z = 50;
#     System.out.println(x + y + z); // 150
#     ```

# %% [markdown]
# - Python - output variables
#   - print() 함수는 종종 변수를 출력하는 데 사용됩니다.
#   - print() 함수에서는 쉼표로 구분된 여러 변수를 출력합니다.
#   - `+` 연산자를 사용하여 여러 변수를 출력할 수도 있습니다.
#   - "Python"과 "is" 뒤에 있는 공백 문자에 주목하세요. 공백이 없으면 결과는 "Pythonisawesome"입니다.
#   - 숫자의 경우 + 문자는 수학 연산자로 작동합니다.
#   - print() 함수에서 + 연산자를 사용하여 문자열과 숫자를 결합하려고 하면 Python에서 오류가 발생합니다.
#   - print() 함수에서 여러 변수를 출력하는 가장 좋은 방법은 쉼표로 구분하는 것입니다. 쉼표는 서로 다른 데이터 유형을 지원합니다.

# %%
x = "Python is awesome"
print(x)

x = "Python"
y = "is"
z = "awesome"
print(x, y, z)

x = "Python "
y = "is "
z = "awesome"
print(x + y + z)

x = 5
y = 10
print(x + y)

x = 5
y = "John"
print(x, y)
# Out:
# Python is awesome
# Python is awesome
# Python is awesome
# 15
# 5 John

# %% [markdown]
# - Java identifiers
#   - 모든 Java 변수는 고유한 이름으로 식별되어야 합니다.
#   - 이러한 고유한 이름을 식별자라고 합니다.
#   - 식별자는 x, y와 같은 짧은 이름이나 age, sum, totalVolume과 같이 보다 설명적인 이름을 사용할 수 있습니다.
#   - 이해하기 쉽고 유지 관리하기 쉬운 코드를 작성하려면 설명적인 이름을 사용하는 것이 좋습니다.
#   ```java
#   // Good
#   int minutesPerHour = 60;
#
#   // OK, but not so easy to understand what m actually is
#   int m = 60;
#   ```
#   - 변수 이름 지정에 대한 일반적인 규칙은 다음과 같습니다.
#     - 이름에는 문자, 숫자, 밑줄, 달러 기호를 포함할 수 있습니다.
#     - 이름은 문자로 시작해야 합니다.
#     - 이름은 소문자로 시작해야 하며 공백을 포함할 수 없습니다.
#     - 이름은 $와 _로 시작할 수도 있습니다.
#     - 이름은 대소문자를 구분합니다("myVar"와 "myvar"는 다른 변수입니다).
#     - 예약어(예: int 또는 boolean과 같은 Java 키워드)는 이름으로 사용할 수 없습니다.

# %% [markdown]
# - Python - global variables
#   - 전역 변수
#     - 함수 외부에서 생성된 변수(이전 페이지의 모든 예제처럼)를 전역 변수라고 합니다.
#     - 전역 변수는 함수 내부와 외부 모두에서 누구나 사용할 수 있습니다.
#     - 함수 외부에서 변수를 생성하고 함수 내부에서 사용합니다.
#     - 함수 내에서 같은 이름의 변수를 생성하면 해당 변수는 지역 변수가 되어 함수 내에서만 사용할 수 있습니다. 같은 이름의 전역 변수는 원래 값을 그대로 유지하며 전역 변수로 사용됩니다.
#     - 전역 변수와 동일한 이름으로 함수 내부에 변수를 생성합니다.
#   - global 키워드
#     - 일반적으로 함수 내에서 변수를 생성하면 해당 변수는 지역 변수가 되어 해당 함수 내에서만 사용할 수 있습니다.
#     - 함수 내에서 전역 변수를 생성하려면 global 키워드를 사용할 수 있습니다.
#       - global 키워드를 사용하면 변수는 글로벌 범위에 속합니다.
#     - 함수 내에서 전역 변수를 변경하려면 global 키워드를 사용하세요.
#       - 함수 내에서 전역 변수의 값을 변경하려면 global 키워드를 사용하여 변수를 참조합니다.

# %%
x = "awesome"

def myfunc():
    print("Python is " + x)

myfunc()
# Out:
# Python is awesome

# %%
x = "awesome"

def myfunc():
    x = "fantastic"
    print("Python is " + x)

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic
# Python is awesome

# %%
def myfunc():
    global x
    x = "fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic

# %%
x = "awesome"

def myfunc():
    global x
    x = "fantastic"

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic

# %% [markdown]
# - Java constants (final)
#   - 상수(final 키워드)
#     - 변수의 값이 변경되지 않도록 하려면 final 키워드를 사용합니다.
#     - final로 선언된 변수는 상수가 되며, 이는 변경할 수 없고 읽기 전용임을 의미합니다.
#     - 변수의 값이 절대 변경되어서는 안 되는 경우 final로 선언해야 합니다. 예를 들어, 한 시간의 분 수나 출생 연도를 다음과 같이 지정할 수 있습니다.
#     ```java
#     final int MINUTES_PER_HOUR = 60;
#     final int BIRTHYEAR = 1980;
#     ```
#     - 관례상 Java에서 final 변수는 일반적으로 대문자로 작성합니다(예: BIRTHYEAR). 필수는 아니지만 코드 가독성을 위해 유용하며 많은 프로그래머에게 일반적인 방식입니다.
