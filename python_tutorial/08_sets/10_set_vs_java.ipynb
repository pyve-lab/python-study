# %% [markdown]
# # 파이썬 세트(Set)와 자바 세트(Set) 비교
#
# 파이썬의 **`set`** 자료형과 자바의 **`java.util.Set`** 인터페이스를 구현한 클래스들(주로 `HashSet`)은 모두 **중복을 허용하지 않고 순서가 없는(Unordered) 요소들의 집합**이라는 핵심 개념을 공유합니다.
# 하지만 각 언어의 특성 및 구현 방식에 따라 중요한 차이점을 보입니다.

# %% [markdown]
# ## 1. 주요 구조 및 특징 비교
#
# | 구분 | 파이썬 Set | 자바 Set (주로 HashSet) |
# | :--- | :--- | :--- |
# | **자료구조 유형** | 내장(Built-in) 자료형 | `java.util.Set` 인터페이스 구현체 (주로 `java.util.HashMap` 기반) |
# | **선언 방식** | 중괄호 `{}` 또는 `set()` 함수 사용 | `Set<Type> mySet = new HashSet<>();` |
# | **가변성 (Mutability)** | **가변(Mutable)**: 항목 추가/제거 가능 | **가변(Mutable)**: 항목 추가/제거 가능 |
# | **불변 세트** | **`frozenset`** 사용 | `Set.of()` (Java 9+) 또는 `Collections.unmodifiableSet()` 사용 |
# | **순서** | 기본적으로 **순서 없음** | `HashSet`: **순서 없음**. `LinkedHashSet`: 삽입 순서 유지. `TreeSet`: 오름차순 정렬됨. |

# %% [markdown]
# ## 2. 집합 연산 방식 비교
#
# 파이썬은 수학적 집합론의 **연산자**를 지원하여 코드가 매우 간결합니다. 자바는 **메서드**를 통해 연산을 수행하며, 보통 원본 세트를 수정합니다.
#
# | 연산 | 파이썬 (Operator) | 파이썬 (Method) | 자바 (Method) | 비고 |
# | :---: | :---: | :---: | :---: | :--- |
# | **합집합 (Union)** | `A \| B` | `A.union(B)` | `target.addAll(other)` | 자바는 원본 `target`을 수정함. |
# | **교집합 (Intersection)** | `A & B` | `A.intersection(B)` | `target.retainAll(other)` | 자바는 원본 `target`을 수정함. |
# | **차집합 (Difference)** | `A - B` | `A.difference(B)` | `target.removeAll(other)` | 자바는 원본 `target`을 수정함. |
# | **대칭 차집합** | `A ^ B` | `A.symmetric_difference(B)` | 별도의 메서드 없음 (직접 구현 필요) | |

# %% [markdown]
# ### 💡 파이썬 `frozenset`의 역할
# 파이썬의 **`frozenset`**은 불변성을 가지기 때문에, 자바의 불변 Set처럼 단순 데이터 보호 외에도 **딕셔너리의 키(Key)**나 다른 세트의 **요소**로 사용될 수 있는 중요한 역할을 수행합니다.
